# %% [markdown]
# TTT-MIM: Test-Time Training with Masked Image Modeling Can Improve Denoising Performance under Distribution Shifts

# %% [markdown]
# ### Test-Time Adaptation to Single Images

# %% [markdown]
# An example to apply our method on one ImageNet image with simulated noise on single GPU.
#
# Different images from the ImageNetImages folder can be selected with --ImageNum argument.
#
# Iteration number, mask ratio, mask patch size and learning rate can be selected as argument.

# %%
# download needed files
# !pip install gdown
# !gdown https://drive.google.com/uc?id=1Fzb9P_FnRibgN05xkFk2CDslmX2D5MPX
# !unzip SingleImageVisualization.zip
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1Fzb9P_FnRibgN05xkFk2CDslmX2D5MPX
# From (redirected): https://drive.google.com/uc?id=1Fzb9P_FnRibgN05xkFk2CDslmX2D5MPX&confirm=t&uuid=624e609d-af43-4c17-9724-746e54477bb0
# To: /content/SingleImageVisualization.zip
# 100% 87.2M/87.2M [00:01<00:00, 76.5MB/s]
# Archive:  SingleImageVisualization.zip
#   inflating: dataset.py
#   inflating: ImageNetImages/n0185567200000031.jpg
#   inflating: ImageNetImages/n0212916500000615.jpg
#   inflating: ImageNetImages/n0443565300000645.jpg
#   inflating: ImageNetImages/val.csv
#   inflating: loss.py
#   inflating: model/0715_ttt_mim_unet_gn_0.005.pth.tar
#   inflating: ttt_mim_online.py
#   inflating: TTT_MIM_SingleImageVisualization.ipynb
#    creating: unet/__pycache__/
#   inflating: unet/__pycache__/unet.cpython-39.pyc
#   inflating: unet/unet.py
#   inflating: utils.py

# %%
# run TTT_MIM for single image
# %run ttt_mim_online.py --dataset imagenet --noise-mode gaussian --noise-var 0.02 --pretrained model/0715_ttt_mim_unet_gn_0.005.pth.tar --niters 5 --lr 1e-4 --mask-ratio 0.4 --mask-patch-size 4 --denoise-loss pd --ImageNum 1 --gpu 0 ImageNetImages/
# Out:
# /content/ttt_mim_online.py:105: UserWarning: You have chosen a specific GPU. This will completely disable data parallelism.
#   warnings.warn('You have chosen a specific GPU. This will completely '
# Use GPU: 0 for training
# => creating model 'unet'
# => loading checkpoint 'model/0715_ttt_mim_unet_gn_0.005.pth.tar'
# => loaded pre-trained model 'model/0715_ttt_mim_unet_gn_0.005.pth.tar'
# => loading data
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [0/3]	Time  0.512 ( 0.512)	Data  0.172 ( 0.172)	Loss 7.3035e-03 (7.3035e-03)	PSNR 29.043 (29.043)
# ...
